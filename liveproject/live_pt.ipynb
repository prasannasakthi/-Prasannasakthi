# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
pip install openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df = pd.read_csv("C:/Users/HP/OneDrive/Desktop/liveproject/why.csv")

# %%
df.head()
# Out:
#       ID Pipeline Repeat deal Repeat inquiry            Stage  \
# 0  84490    Sales           N              Y  Tele Counselled
# 1  84138    Sales           N              N         New Lead
# 2  80194    Sales           N              N         New Lead
# 3  77118    Sales           N              N  Tele Counselled
# 4  89606    Sales           N              Y   Enquired Again
#
#          Responsible                                          Deal Name  \
# 0  Sathiya Natarajan                   Complete CRM form "Navbar & CTA"
# 1       Gayyo Lovees  Complete CRM form "IGS - Merit Based Scholarsh...
# 2       Gayyo Lovees  Complete CRM form "IGS - Merit Based Scholarsh...
# 3           Kaveri C                   Complete CRM form "Navbar & CTA"
# 4   Navanitha Sakthi                   Complete CRM form "Navbar & CTA"
#
#            Type      Source  Income  ... Contact: Created by  \
# 0  not selected     Website       0  ...                 NaN
# ...

# %%
df.shape
# Out:
# (1506, 48)

# %%
df.info(
)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1506 entries, 0 to 1505
# Data columns (total 48 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   ID                                         1506 non-null   object
#  1   Pipeline                                   1506 non-null   object
#  2   Repeat deal                                1506 non-null   object
#  3   Repeat inquiry                             1506 non-null   object
#  4   Stage                                      1506 non-null   object
#  5   Responsible                                1506 non-null   object
#  6   Deal Name                                  1506 non-null   object
#  7   Type                                       1506 non-null   object
#  8   Source                                     1499 non-null   object
#  9   Income                                     1506 non-null   int64
# ...

# %%
cleaned_df=df['Stage'].dropna().unique()
cleaned_df
# Out:
# array(['Tele Counselled', 'New Lead', 'Enquired Again',
#        'Contact Attempted', 'Lost Deal', 'Follow Up', 'Other Courses',
#        'Interested | Join Later', 'Interested | Fees Not Affordable',
#        'Enrolled', 'Scheduled Walk-in', 'Not Eligible', 'Not Enquired',
#        'Not Reachable', 'Not Picking', 'Counselled',
#        'Internship(Enquiry)', 'Invalid/Irrelevant Number', 'Duplicate',
#        'Switched Off', 'Hot Prospect', 'Interested | Parents Rejected'],
#       dtype=object)

# %%
conversion_stages = df['Stage'].isin(['Joined', 'Closed Won'])

# %%
conversion_stages
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1501    False
# 1502    False
# 1503    False
# 1504    False
# 1505    False
# Name: Stage, Length: 1506, dtype: bool

# %%
converted_leads=df["ID"].count()
converted_leads
# Out:
# np.int64(1506)

# %%
df["Source"and"Closed"].value_counts()
# Out:
# Closed
# no     1202
# yes     304
# Name: count, dtype: int64

# %% [markdown]
# whytap Conversion & performance of leeds

# %%
Conversion_performance= df.groupby("Source")["Closed"].value_counts().unstack(fill_value=0)
Conversion_performance
# Out:
# Closed              no  yes
# Source
# CRM form            21    4
# Call                15    5
# E-Mail               1    0
# Event                1    1
# Google AD           23   15
# Influencer          11    0
# Instagram           48    6
# Meta AD            816  182
# Repeat sales        17   10
# Student Reference    2    1
# Walk-in              5    1
# Website             62   12
# WhatsApp           173   66
# not selected         0    1

# %%
high_cover=Conversion_performance.sort_values(by=["yes","no"],ascending=[False,False]).reset_index()

# %%
high_cover
# Out:
# Closed             Source   no  yes
# 0                 Meta AD  816  182
# 1                WhatsApp  173   66
# 2               Google AD   23   15
# 3                 Website   62   12
# 4            Repeat sales   17   10
# 5               Instagram   48    6
# 6                    Call   15    5
# 7                CRM form   21    4
# 8                 Walk-in    5    1
# 9       Student Reference    2    1
# 10                  Event    1    1
# 11           not selected    0    1
# 12             Influencer   11    0
# 13                 E-Mail    1    0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1506 entries, 0 to 1505
# Data columns (total 48 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   ID                                         1506 non-null   object
#  1   Pipeline                                   1506 non-null   object
#  2   Repeat deal                                1506 non-null   object
#  3   Repeat inquiry                             1506 non-null   object
#  4   Stage                                      1506 non-null   object
#  5   Responsible                                1506 non-null   object
#  6   Deal Name                                  1506 non-null   object
#  7   Type                                       1506 non-null   object
#  8   Source                                     1499 non-null   object
#  9   Income                                     1506 non-null   int64
# ...

# %%
df.dtypes
# Out:
# ID                                            object
# Pipeline                                      object
# Repeat deal                                   object
# Repeat inquiry                                object
# Stage                                         object
# Responsible                                   object
# Deal Name                                     object
# Type                                          object
# Source                                        object
# Income                                         int64
# Currency                                      object
# Contact                                       object
# Closed                                        object
# Created                                       object
# Created by                                    object
# Modified                                      object
# Modified by                                   object
# Start date                                    object
# ...

# %%
df.groupby("Select a Course")["Closed"].value_counts().unstack(fill_value="unselect")
# Out:
# Closed                                              no       yes
# Select a Course
# Basic to Advanced Video Editing with AI              1  unselect
# Certification in Data Analytics                      7  unselect
# Other                                               13         3
# PG Certification in AI powered Data Science          5         3
# PG Certification in AI powered Digital Marketing    19         1
# PG Certification in AI powered Full Stack Devel...  13  unselect

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1506 entries, 0 to 1505
# Data columns (total 48 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   ID                                         1506 non-null   object
#  1   Pipeline                                   1506 non-null   object
#  2   Repeat deal                                1506 non-null   object
#  3   Repeat inquiry                             1506 non-null   object
#  4   Stage                                      1506 non-null   object
#  5   Responsible                                1506 non-null   object
#  6   Deal Name                                  1506 non-null   object
#  7   Type                                       1506 non-null   object
#  8   Source                                     1499 non-null   object
#  9   Income                                     1506 non-null   int64
# ...

# %%
df[df["Contact"] == "Balakumar"][df["Course pitched"]== "Certification in Data Analytics"]
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_16856\2254234334.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df[df["Contact"] == "Balakumar"][df["Course pitched"]== "Certification in Data Analytics"]
#          ID Pipeline Repeat deal Repeat inquiry     Stage Responsible  \
# 1346  64918    Sales           N              N  Enrolled  Sophia N D
# 1470  #####    Sales           N              N  Enrolled  Sophia N D
#
#      Deal Name          Type Source  Income  ... Contact: Created by  \
# 1346      Bala  not selected   Call   25000  ...          Sophia N D
# 1470      Bala  not selected   Call   25000  ...          Sophia N D
#
#          Contact: Created on Contact: Modified by    Contact: Modified on  \
# 1346  06.08.2025 09:05:09 am           Ajin G Das  08.08.2025 02:53:02 pm
# 1470  06.08.2025 09:05:09 am           Ajin G Das  08.08.2025 02:53:02 pm
#
#      Contact: Educational Qualification Contact: Select a Course  \
# ...

# %%
df[df["Course pitched"]== "Certification in Data Analytics"]
# Out:
#          ID Pipeline Repeat deal Repeat inquiry            Stage  \
# 3     77118    Sales           N              N  Tele Counselled
# 7     76438    Sales           N              N  Tele Counselled
# 17    73930    Sales           N              Y        Follow Up
# 18    #####    Sales           N              Y        Follow Up
# 21    62610    Sales           N              N  Tele Counselled
# ...     ...      ...         ...            ...              ...
# 1489  #####    Sales           N              N      Not Picking
# 1490   5568    Sales           N              N  Tele Counselled
# 1492  77770    Sales           N              N  Tele Counselled
# 1496  64504    Sales           N              Y     Not Eligible
# 1499  #####    Sales           N              N        Follow Up
#
#             Responsible                                          Deal Name  \
# 3              Kaveri C                   Complete CRM form "Navbar & CTA"
# ...

# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
df['Created']=pd.to_datetime(df['Created'])
df["Created"] = df["Created"].dt.date
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_16856\1624590741.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Created']=pd.to_datetime(df['Created'])

# %%
print(df['Closed'].unique())
# Out:
# ['no' 'yes']

# %%
df['Closed'] = df['Closed'].astype('category')

# %%
df["Modified"]=pd.to_datetime(df["Modified"])
df["Start date"]=pd.to_datetime(df["Start date"])
df["Assumed close date"]=pd.to_datetime(df["Assumed close date"])
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_16856\4045302491.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df["Modified"]=pd.to_datetime(df["Modified"])
# C:\Users\HP\AppData\Local\Temp\ipykernel_16856\4045302491.py:2: UserWarning: Parsing dates in %d.%m.%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df["Start date"]=pd.to_datetime(df["Start date"])
# C:\Users\HP\AppData\Local\Temp\ipykernel_16856\4045302491.py:3: UserWarning: Parsing dates in %d.%m.%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df["Assumed close date"]=pd.to_datetime(df["Assumed close date"])

# %%
df.head(2)
# Out:
#       ID Pipeline Repeat deal Repeat inquiry            Stage  \
# 0  84490    Sales           N              Y  Tele Counselled
# 1  84138    Sales           N              N         New Lead
#
#          Responsible                                          Deal Name  \
# 0  Sathiya Natarajan                   Complete CRM form "Navbar & CTA"
# 1       Gayyo Lovees  Complete CRM form "IGS - Merit Based Scholarsh...
#
#            Type      Source  Income  ... Contact: Created by  \
# 0  not selected     Website       0  ...                 NaN
# 1  not selected  Influencer       0  ...                 NaN
#
#       Contact: Created on Contact: Modified by    Contact: Modified on  \
# 0  22.09.2025 01:58:52 pm    Sathiya Natarajan  22.09.2025 06:31:41 pm
# 1  21.09.2025 06:58:31 am                  NaN  21.09.2025 06:58:31 am
#
#   Contact: Educational Qualification         Contact: Select a Course  \
# 0                                NaN                              NaN
# ...

# %% [markdown]
# Sales_by_person

# %%
yes= df.groupby("Responsible")["Closed"].value_counts().unstack(fill_value=0)
yes
# Out:
# Closed                     no  yes
# Responsible
# Ahila M                     2    0
# Dhanalakshmi D             37    5
# Gayyo Lovees               48    1
# Harini P                  139   49
# Kaveri C                  149   43
# Meena Arunachalam         110   32
# Monisha R                   2    0
# Navanitha Sakthi           40    0
# Naveen kumar               55    9
# Pratheep Kumar P          143   19
# Rajalakshmi Govindarajan  142   18
# Ramya Sathish              47   74
# Sathiya Natarajan         110   15
# Sophia N D                153   31
# Supraja Baalajee           12    4
# Vignesh R                  13    4

# %%
Conversion_performance= df.groupby("Source")["Closed"].value_counts().unstack(fill_value=0)
Conversion_performance
# Out:
# Closed              no  yes
# Source
# CRM form            21    4
# Call                15    5
# E-Mail               1    0
# Event                1    1
# Google AD           23   15
# Influencer          11    0
# Instagram           48    6
# Meta AD            816  182
# Repeat sales        17   10
# Student Reference    2    1
# Walk-in              5    1
# Website             62   12
# WhatsApp           173   66
# not selected         0    1

# %%
yes_count_by_resp=df[df["Closed"].isin(["yes", "no"])]
yes_count_by_resp
# Out:
#          ID Pipeline Repeat deal Repeat inquiry              Stage  \
# 0     84490    Sales           N              Y    Tele Counselled
# 1     84138    Sales           N              N           New Lead
# 2     80194    Sales           N              N           New Lead
# 3     77118    Sales           N              N    Tele Counselled
# 4     89606    Sales           N              Y     Enquired Again
# ...     ...      ...         ...            ...                ...
# 1501  #####    Sales           N              N    Tele Counselled
# 1502  #####    Sales           N              N  Contact Attempted
# 1503  #####    Sales           N              N  Contact Attempted
# 1504  #####    Sales           N              N      Other Courses
# 1505  #####    Sales           N              N  Contact Attempted
#
#             Responsible                                          Deal Name  \
# 0     Sathiya Natarajan                   Complete CRM form "Navbar & CTA"
# ...

# %%
sale_summary= yes_count_by_resp.groupby(["Responsible",'Course pitched']).size().reset_index(name="count")
sale_summary
# Out:
#                  Responsible                           Course pitched  count
# 0             Dhanalakshmi D                           Data Analytics      6
# 1             Dhanalakshmi D                        Digital Marketing     18
# 2             Dhanalakshmi D                                      FSD     13
# 3               Gayyo Lovees                             Data Science      1
# 4               Gayyo Lovees                        Digital Marketing     22
# 5               Gayyo Lovees                                      FSD      1
# 6                   Harini P                           Data Analytics      7
# 7                   Harini P                             Data Science      3
# 8                   Harini P                        Digital Marketing     62
# 9                   Harini P                                      FSD     12
# 10                  Harini P                                      MSD      2
# ...

# %%
pivot_summary= sale_summary.pivot_table(
    index=['Responsible', 'Course pitched'],
    columns='Closed',
    values='count',
    fill_value=0
).reset_index()
pivot_summary
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_16856\1622320456.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   pivot_summary= sale_summary.pivot_table(
# Closed Responsible                           Course pitched   no  yes
# 0          Ahila M  Basic to Advanced Video Editing with AI  0.0  0.0
# 1          Ahila M                           Data Analytics  0.0  0.0
# 2          Ahila M                             Data Science  0.0  0.0
# 3          Ahila M                        Digital Marketing  0.0  0.0
# 4          Ahila M                                      FSD  0.0  0.0
# ..             ...                                      ...  ...  ...
# 91       Vignesh R                           Data Analytics  2.0  1.0
# 92       Vignesh R                             Data Science  0.0  0.0
# ...

# %%
sale_summary = yes_count_by_resp.groupby(["Responsible", "Course pitched", "Closed"]).size().reset_index(name="count")
sale_summary
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_16856\942520838.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   sale_summary = yes_count_by_resp.groupby(["Responsible", "Course pitched", "Closed"]).size().reset_index(name="count")
#     Responsible                           Course pitched Closed  count
# 0       Ahila M  Basic to Advanced Video Editing with AI     no      0
# 1       Ahila M  Basic to Advanced Video Editing with AI    yes      0
# 2       Ahila M                           Data Analytics     no      0
# 3       Ahila M                           Data Analytics    yes      0
# 4       Ahila M                             Data Science     no      0
# ..          ...                                      ...    ...    ...
# ...

# %%
pivot_summary = sale_summary.pivot_table(
    index=['Responsible', 'Course pitched'],
    columns='Closed',
    values='count',
    fill_value=0
).reset_index()
pivot_summary
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_16856\571553024.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   pivot_summary = sale_summary.pivot_table(
# Closed Responsible                           Course pitched   no  yes
# 0          Ahila M  Basic to Advanced Video Editing with AI  0.0  0.0
# 1          Ahila M                           Data Analytics  0.0  0.0
# 2          Ahila M                             Data Science  0.0  0.0
# 3          Ahila M                        Digital Marketing  0.0  0.0
# 4          Ahila M                                      FSD  0.0  0.0
# ..             ...                                      ...  ...  ...
# 91       Vignesh R                           Data Analytics  2.0  1.0
# 92       Vignesh R                             Data Science  0.0  0.0
# ...

# %%
with pd.ExcelWriter("whytapfile.xlsx", engine='openpyxl') as writer:
    high_cover.to_excel(writer, sheet_name='conversion', index=False)
    pivot_summary .to_excel(writer, sheet_name='Sales_count', index=False)
    result.to_excel(writer, sheet_name='DA', index=False)

# %%
df["Course pitched"]
# Out:
# 0       Digital Marketing
# 1                     NaN
# 2                     NaN
# 3          Data Analytics
# 4                     NaN
#               ...
# 1501    Digital Marketing
# 1502                  NaN
# 1503                  NaN
# 1504                  NaN
# 1505                  NaN
# Name: Course pitched, Length: 1506, dtype: object

# %%
df["Contact: First name"],df["Course pitched"]==("Certification in Data Analytics")
# Out:
# (0           Jaya Priya
#  1          Rajeshkumar
#  2            Samuvel.M
#  3             Subin SK
#  4        Adhisriramesh
#               ...
#  1501    Santhosh kumar
#  1502     SETHUPATHI. M
#  1503        Adithyan C
#  1504             Madan
#  1505      Nirmal Kumar
#  Name: Contact: First name, Length: 1506, dtype: object,
#  0       False
#  1       False
#  2       False
#  3       False
#  4       False
#          ...
#  1501    False
#  1502    False
#  1503    False
#  1504    False
#  1505    False
#  Name: Course pitched, Length: 1506, dtype: bool)

# %%
da_df = df[(df['Course pitched'] == 'Data Analytics') &(df["Closed"]=="yes")]

# %%
da_df
# Out:
#          ID Pipeline Repeat deal Repeat inquiry  \
# 170   81526    Sales          NO             NO
# 374   72556    Sales          NO             NO
# 413   #####    Sales          NO             NO
# 523   82222    Sales          NO             NO
# 526   79968    Sales          NO             NO
# 529   77864    Sales          NO             NO
# 567   #####    Sales          NO             NO
# 573   #####    Sales          NO             NO
# 608   #####    Sales          NO             NO
# 617   #####    Sales          NO             NO
# 689   64686    Sales          NO             NO
# 730   #####    Sales          NO             NO
# 782   68176    Sales          NO             NO
# 952   70480    Sales          NO             NO
# 1201  84098    Sales          NO             NO
# 1346  64918    Sales          NO             NO
# 1351  61834    Sales          NO             NO
# 1353  16896    Sales          NO             NO
# ...

# %%
result = da_df[['Responsible','Contact: First name', 'Course pitched']].reset_index()

# %%
result
# Out:
#     index               Responsible Contact: First name  Course pitched
# 0     170                  Harini P                Asha  Data Analytics
# 1     374                  Kaveri C      john william V  Data Analytics
# 2     413                  Kaveri C      john william V  Data Analytics
# 3     523         Meena Arunachalam                 கவி  Data Analytics
# 4     526         Meena Arunachalam              Sanjay  Data Analytics
# 5     529         Meena Arunachalam          Harisankar  Data Analytics
# 6     567         Meena Arunachalam                 கவி  Data Analytics
# 7     573         Meena Arunachalam              Sanjay  Data Analytics
# 8     608         Meena Arunachalam       BABYSHALINI R  Data Analytics
# 9     617         Meena Arunachalam          Harisankar  Data Analytics
# 10    689              Naveen kumar         Sivaranjini  Data Analytics
# 11    730              Naveen kumar         Sivaranjini  Data Analytics
# ...

# %%
df["Repeat inquiry"]=df["Repeat inquiry"].replace('Y', "YES")

# %%
df["Repeat inquiry"]=df["Repeat inquiry"].replace("N", "NO")

# %%
df["Repeat deal"]=df["Repeat deal"].replace('Y', "YES")

# %%
df["Repeat deal"]=df["Repeat deal"].replace("N", "NO")

# %%
df.head(2)
# Out:
#       ID Pipeline Repeat deal Repeat inquiry            Stage  \
# 0  84490    Sales          NO            YES  Tele Counselled
# 1  84138    Sales          NO             NO         New Lead
#
#          Responsible                                          Deal Name  \
# 0  Sathiya Natarajan                   Complete CRM form "Navbar & CTA"
# 1       Gayyo Lovees  Complete CRM form "IGS - Merit Based Scholarsh...
#
#            Type      Source  Income  ... Contact: Created by  \
# 0  not selected     Website       0  ...                 NaN
# 1  not selected  Influencer       0  ...                 NaN
#
#       Contact: Created on Contact: Modified by    Contact: Modified on  \
# 0  22.09.2025 01:58:52 pm    Sathiya Natarajan  22.09.2025 06:31:41 pm
# 1  21.09.2025 06:58:31 am                  NaN  21.09.2025 06:58:31 am
#
#   Contact: Educational Qualification         Contact: Select a Course  \
# 0                                NaN                              NaN
# ...

# %%
grouped = df.groupby('Contact: Educational Qualification')['Course pitched'].value_counts().reset_index()
grouped
# Out:
#                     Contact: Educational Qualification  \
# 0                                           12+diploma
# 1                                                 12th
# 2    12th pass and bsc computer science 2year I am ...
# 3                                           8098783393
# 4                                           9344759243
# ..                                                 ...
# 190                                  postgraduate_(pg)
# 191                                  postgraduate_(pg)
# 192                                            student
# 193                                            student
# 194                                            student
#
#                                         Course pitched  count
# 0                      Certification in Data Analytics      1
# 1    PG Certification in AI powered Full Stack Deve...      1
# 2     PG Certification in AI powered Digital Marketing      1
# ...

# %%
grouped = (df.groupby('Contact: Educational Qualification')['Course pitched'].value_counts().reset_index(name='Count').sort_values(by='Count', ascending=False))
grouped
# Out:
#     Contact: Educational Qualification     Course pitched  Count
# 54                                 BSC  Digital Marketing     27
# 18                               B.com  Digital Marketing     27
# 48                                  BE  Digital Marketing     23
# 100                                MBA  Digital Marketing     21
# 19                               B.com     Data Analytics     20
# ..                                 ...                ...    ...
# 108                                MCA       Data Science      1
# 119                                bba       Data Science      1
# 115                               Mcom     Data Analytics      1
# 130                non-it_professional                MSD      1
# 132                  postgraduate_(pg)     Data Analytics      1
#
# [136 rows x 3 columns]

# %%
df["Contact: Educational Qualification"]=df["Contact: Educational Qualification"].replace("Bsc CS","BSC")
df["Contact: Educational Qualification"]=df["Contact: Educational Qualification"].replace("Bsc IT","BSC")
df["Contact: Educational Qualification"]=df["Contact: Educational Qualification"].replace("BSC computer science","BSC")
df["Contact: Educational Qualification"]=df["Contact: Educational Qualification"].replace("Bsc Maths","BSC")
df["Contact: Educational Qualification"]=df["Contact: Educational Qualification"].replace("B.sc maths","BSC")
df["Contact: Educational Qualification"]=df["Contact: Educational Qualification"].replace("B.sc computer science","BSC")
df["Contact: Educational Qualification"]=df["Contact: Educational Qualification"].replace("B.sc","BSC")
df["Contact: Educational Qualification"]=df["Contact: Educational Qualification"].replace("B.Sc Information Technology","BSC")
df["Contact: Educational Qualification"]=df["Contact: Educational Qualification"].replace("bsc it","BSC")
df["Contact: Educational Qualification"]=df["Contact: Educational Qualification"].replace("Bsc physics","BSC")
df["Contact: Educational Qualification"]=df["Contact: Educational Qualification"].replace("Bsc computer science","BSC")
df["Contact: Educational Qualification"]=df["Contact: Educational Qualification"].replace("BSc.,AGRICULTURE","BSC")
df["Contact: Educational Qualification"]=df["Contact: Educational Qualification"].replace("BSC. Computer science","BSC")
df["Contact: Educational Qualification"]=df["Contact: Educational Qualification"].replace("Bsc Cs","BSC")
df["Contact: Educational Qualification"]=df["Contact: Educational Qualification"].replace("Bsc.CS","BSC")
df["Contact: Educational Qualification"]=df["Contact: Educational Qualification"].replace("Bsc visual communication","BSC")
df["Contact: Educational Qualification"]=df["Contact: Educational Qualification"].replace("Bsc.Computer science","BSC")
df["Contact: Educational Qualification"]=df["Contact: Educational Qualification"].replace("Bsc Mathematics with computer applications","BSC")
df["Contact: Educational Qualification"]=df["Contact: Educational Qualification"].replace("Bsc chemistry,mba","BSC")
df["Contact: Educational Qualification"]=df["Contact: Educational Qualification"].replace("Bsc microbiology","BSC")
df["Contact: Educational Qualification"]=df["Contact: Educational Qualification"].replace("Bsc(nursing)","BSC")
df["Contact: Educational Qualification"]=df["Contact: Educational Qualification"].replace("Msc","MSC")
df["Contact: Educational Qualification"]=df["Contact: Educational Qualification"].replace("Msc Biotechnology","MSC")
df["Contact: Educational Qualification"]=df["Contact: Educational Qualification"].replace("Msc CS","MSC")
df["Contact: Educational Qualification"]=df["Contact: Educational Qualification"].replace("Msc Chemistry","MSC")
df["Contact: Educational Qualification"]=df["Contact: Educational Qualification"].replace("Msc Computer Science","MSC")
df["Contact: Educational Qualification"]=df["Contact: Educational Qualification"].replace("Msc Costume design and fashion in psg College of arts and science coimbatore","MSC")
df["Contact: Educational Qualification"]=df["Contact: Educational Qualification"].replace("Msc Maths","MSC")
df["Contact: Educational Qualification"]=df["Contact: Educational Qualification"].replace("Msc Microbiology","MSC")
df["Contact: Educational Qualification"]=df["Contact: Educational Qualification"].replace("Msc Physics","MSC")
df["Contact: Educational Qualification"]=df["Contact: Educational Qualification"].replace("Msc botany","MSC")
df["Contact: Educational Qualification"]=df["Contact: Educational Qualification"].replace("Msc computer science","MSC")
df["Contact: Educational Qualification"]=df["Contact: Educational Qualification"].replace("Msc data analytics","MSC")
df["Contact: Educational Qualification"]=df["Contact: Educational Qualification"].replace("Msc information technology","MSC")
df["Contact: Educational Qualification"]=df["Contact: Educational Qualification"].replace("Msc physics","MSC")
df["Contact: Educational Qualification"]=df["Contact: Educational Qualification"].replace("Msc, Microbiology","MSC")
df["Contact: Educational Qualification"]=df["Contact: Educational Qualification"].replace("MBA F&O","MBA")
df["Contact: Educational Qualification"]=df["Contact: Educational Qualification"].replace("MBA HR","MBA")
df["Contact: Educational Qualification"]=df["Contact: Educational Qualification"].replace("MBA in marketing and IT analytics","MBA")
df["Contact: Educational Qualification"]=df["Contact: Educational Qualification"].replace("MBA ( FINANCE/ HR )","MBA")
df["Contact: Educational Qualification"]=df["Contact: Educational Qualification"].replace("MBA 2025 passout in specialization of hr and finance","MBA")
df["Contact: Educational Qualification"]=df["Contact: Educational Qualification"].replace("M.B.A","MBA")
df["Contact: Educational Qualification"]=df["Contact: Educational Qualification"].replace("Mba","MBA")
df["Contact: Educational Qualification"]=df["Contact: Educational Qualification"].replace("B. tech/ MBA","MBA")
df["Contact: Educational Qualification"]=df["Contact: Educational Qualification"].replace("Bcom, MBA","MBA")
df["Contact: Educational Qualification"]=df["Contact: Educational Qualification"].replace("Bcom, MBA","MBA")
df["Contact: Educational Qualification"]=df["Contact: Educational Qualification"].replace("Mba","MBA")
df["Contact: Educational Qualification"]=df["Contact: Educational Qualification"].replace("BE and MBA","MBA")
df["Contact: Educational Qualification"]=df["Contact: Educational Qualification"].replace("Bcom, MBA","MBA")
df["Contact: Educational Qualification"]=df["Contact: Educational Qualification"].replace("B. tech/ MBA","MBA")
df["Contact: Educational Qualification"]=df["Contact: Educational Qualification"].replace("B.com, MBA hr","MBA")
df["Contact: Educational Qualification"]=df["Contact: Educational Qualification"].replace("B.com ca MBA hr","MBA")
df["Contact: Educational Qualification"]=df["Contact: Educational Qualification"].replace("B.Com (Computer Applications)","MBA")
df["Contact: Educational Qualification"]=df["Contact: Educational Qualification"].replace("B.com","B.com")
df["Contact: Educational Qualification"]=df["Contact: Educational Qualification"].replace("b.com","B.com")
df["Contact: Educational Qualification"]=df["Contact: Educational Qualification"].replace("B.com CA","B.com")
df["Contact: Educational Qualification"]=df["Contact: Educational Qualification"].replace("B.com ca","B.com")
df["Contact: Educational Qualification"]=df["Contact: Educational Qualification"].replace("B.com corporate secretaryship","B.com")
df["Contact: Educational Qualification"]=df["Contact: Educational Qualification"].replace("B.com CS","B.com")
df["Contact: Educational Qualification"]=df["Contact: Educational Qualification"].replace("B.com general","B.com")
df["Contact: Educational Qualification"]=df["Contact: Educational Qualification"].replace("B.com general final year student","B.com")
df["Contact: Educational Qualification"]=df["Contact: Educational Qualification"].replace("B.Com(Business Analytics)","B.com")
df["Contact: Educational Qualification"]=df["Contact: Educational Qualification"].replace("B.com.c.a","B.com")
df["Contact: Educational Qualification"]=df["Contact: Educational Qualification"].replace("Bcom","B.com")
df["Contact: Educational Qualification"]=df["Contact: Educational Qualification"].replace("B com","B.com")
df["Contact: Educational Qualification"]=df["Contact: Educational Qualification"].replace("B com","B.com")
df["Contact: Educational Qualification"]=df["Contact: Educational Qualification"].replace("Santhoshkumar B.COM","B.com")
df["Contact: Educational Qualification"]=df["Contact: Educational Qualification"].replace("Bcom ISM","B.com")
df["Contact: Educational Qualification"]=df["Contact: Educational Qualification"].replace("Bcom general competed","B.com")
df["Contact: Educational Qualification"]=df["Contact: Educational Qualification"].replace("Bcom cs","B.com")
df["Contact: Educational Qualification"]=df["Contact: Educational Qualification"].replace("Bcom CA","B.com")
df["Contact: Educational Qualification"]=df["Contact: Educational Qualification"].replace("BCom","B.com")
df["Contact: Educational Qualification"]=df["Contact: Educational Qualification"].replace("Bcom computer application","B.com")
df["Contact: Educational Qualification"]=df["Contact: Educational Qualification"].replace("B","B.com")
df["Contact: Educational Qualification"]=df["Contact: Educational Qualification"].replace("Bsc Agri","BSC")
df["Contact: Educational Qualification"]=df["Contact: Educational Qualification"].replace("Bsc chemistry","BSC")
df["Contact: Educational Qualification"]=df["Contact: Educational Qualification"].replace("Bsc chemistry","BSC")
df["Contact: Educational Qualification"]=df["Contact: Educational Qualification"].replace("Bsc chemistry","BSC")
df["Contact: Educational Qualification"]=df["Contact: Educational Qualification"].replace("BSC Computer science","BSC")
df["Contact: Educational Qualification"]=df["Contact: Educational Qualification"].replace("Bsc Computer Science","BSC")
df["Contact: Educational Qualification"]=df["Contact: Educational Qualification"].replace("Bsc cs","BSC")
df["Contact: Educational Qualification"]=df["Contact: Educational Qualification"].replace("BSC maths","BSC")
df["Contact: Educational Qualification"]=df["Contact: Educational Qualification"].replace("BSC Multimedia animation","BSC")
df["Contact: Educational Qualification"]=df["Contact: Educational Qualification"].replace("Bsc Viscom","BSC")
df["Contact: Educational Qualification"]=df["Contact: Educational Qualification"].replace("B sc Data Science","BSC")
df["Contact: Educational Qualification"]=df["Contact: Educational Qualification"].replace("Bsc.CS","BSC")
df["Contact: Educational Qualification"]=df["Contact: Educational Qualification"].replace("12th pass and bsc computer science 2year I am study","BSC")
df["Contact: Educational Qualification"]=df["Contact: Educational Qualification"].replace("Bsc","BSC")
df["Course pitched"]=df["Course pitched"].replace("PG Certification in AI powered Digital Marketing","Digital Marketing")
df["Course pitched"]=df["Course pitched"].replace("Certification in Data Analytics","Data Analytics")
df["Course pitched"]=df["Course pitched"].replace("PG Certification in AI powered Data Science","Data Science")
df["Course pitched"]=df["Course pitched"].replace("PG Certification in AI powered Full Stack Development","FSD")
df["Course pitched"]=df["Course pitched"].replace("PG Certification in MERN Stack Development","MSD")
df["Contact: Educational Qualification"]=df["Contact: Educational Qualification"].replace("B Sc. Maths","BSC")
df["Contact: Educational Qualification"]=df["Contact: Educational Qualification"].replace("B. Sc., chemistry","BSC")
df["Contact: Educational Qualification"]=df["Contact: Educational Qualification"].replace("B. SC VISCOM","BSC")
df["Contact: Educational Qualification"]=df["Contact: Educational Qualification"].replace("Bca","BCA")
df["Contact: Educational Qualification"]=df["Contact: Educational Qualification"].replace("BCA 2020-2023","BSC")
df["Contact: Educational Qualification"]=df["Contact: Educational Qualification"].replace("Be","BE")
df["Contact: Educational Qualification"]=df["Contact: Educational Qualification"].replace("BE (ECE)","BE")
df["Contact: Educational Qualification"]=df["Contact: Educational Qualification"].replace("BE Aeronautical","BE")
df["Contact: Educational Qualification"]=df["Contact: Educational Qualification"].replace("BE Bio Medical","BE")
df["Contact: Educational Qualification"]=df["Contact: Educational Qualification"].replace("BE Biomedical engg","BE")
df["Contact: Educational Qualification"]=df["Contact: Educational Qualification"].replace("BE Civil","BE")
df["Contact: Educational Qualification"]=df["Contact: Educational Qualification"].replace("BE civil engineering","BE")
df["Contact: Educational Qualification"]=df["Contact: Educational Qualification"].replace("BE computer science Engineering","BE")
df["Contact: Educational Qualification"]=df["Contact: Educational Qualification"].replace("BE CS","BE")
df["Contact: Educational Qualification"]=df["Contact: Educational Qualification"].replace("BE CSE","BE")
df["Contact: Educational Qualification"]=df["Contact: Educational Qualification"].replace("BE ECE","BE")
df["Contact: Educational Qualification"]=df["Contact: Educational Qualification"].replace("Be in ece","BE")
df["Contact: Educational Qualification"]=df["Contact: Educational Qualification"].replace("BE Mech","BE")
df["Contact: Educational Qualification"]=df["Contact: Educational Qualification"].replace("BE mech","BE")
df["Contact: Educational Qualification"]=df["Contact: Educational Qualification"].replace("BE MECHANICAL","BE")
df["Contact: Educational Qualification"]=df["Contact: Educational Qualification"].replace("BE(ece)","BE")
df["Contact: Educational Qualification"]=df["Contact: Educational Qualification"].replace("Be.cs","BE")
df["Contact: Educational Qualification"]=df["Contact: Educational Qualification"].replace("be.eee","BE")
df["Contact: Educational Qualification"]=df["Contact: Educational Qualification"].replace("B. E","BE")
df["Contact: Educational Qualification"]=df["Contact: Educational Qualification"].replace("B. E (cse)","BE")
df["Contact: Educational Qualification"]=df["Contact: Educational Qualification"].replace("B. E mech","BE")
df["Contact: Educational Qualification"]=df["Contact: Educational Qualification"].replace("B.E","BE")
df["Contact: Educational Qualification"]=df["Contact: Educational Qualification"].replace("B.E (EEE)","BE")
df["Contact: Educational Qualification"]=df["Contact: Educational Qualification"].replace("B.E cse","BE")
df["Contact: Educational Qualification"]=df["Contact: Educational Qualification"].replace("B.E EEE","BE")
df["Contact: Educational Qualification"]=df["Contact: Educational Qualification"].replace("B.E Mechanical Engineering","BE")
df["Contact: Educational Qualification"]=df["Contact: Educational Qualification"].replace("B.E(mechanical)","BE")
df["Contact: Educational Qualification"]=df["Contact: Educational Qualification"].replace("B.E. Computer Science And Engineering","BE")
df["Contact: Educational Qualification"]=df["Contact: Educational Qualification"].replace("B.E-ECE","BE")
df["Contact: Educational Qualification"]=df["Contact: Educational Qualification"].replace("BE cs","BE")
df["Contact: Educational Qualification"]=df["Contact: Educational Qualification"].replace("M.sc","MSC")
df["Contact: Educational Qualification"]=df["Contact: Educational Qualification"].replace("M. Sc (Statistics)","MSC")
df["Contact: Educational Qualification"]=df["Contact: Educational Qualification"].replace("M.sc., Chemistry","MSC")
df["Contact: Educational Qualification"]=df["Contact: Educational Qualification"].replace("M.sc., IT","MSC")
df["Contact: Educational Qualification"]=df["Contact: Educational Qualification"].replace("MSC Biotech","MSC")
df["Contact: Educational Qualification"]=df["Contact: Educational Qualification"].replace("MSc computer science","MSC")
df["Contact: Educational Qualification"]=df["Contact: Educational Qualification"].replace("Msc Computer science","MSC")
df["Contact: Educational Qualification"]=df["Contact: Educational Qualification"].replace("MSC IT","MSC")
df["Contact: Educational Qualification"]=df["Contact: Educational Qualification"].replace("Msg computer science","MSC")

# %%
df["Contact: Educational Qualification"]=df["Contact: Educational Qualification"].replace("mca","MCA")
df["Contact: Educational Qualification"]=df["Contact: Educational Qualification"].replace("I am MCA completed in 2024","MCA")
df["Contact: Educational Qualification"]=df["Contact: Educational Qualification"].replace("Mca","MCA")
df["Contact: Educational Qualification"]=df["Contact: Educational Qualification"].replace("MCA","MCA")
df["Contact: Educational Qualification"]=df["Contact: Educational Qualification"].replace("Master of Computer Application (MCA)","MCA")
df["Contact: Educational Qualification"]=df["Contact: Educational Qualification"].replace("Master of Computer Application (MCA)","MCA")
df["Contact: Educational Qualification"]=df["Contact: Educational Qualification"].replace("Master of computer Application","MCA")
df["Contact: Educational Qualification"]=df["Contact: Educational Qualification"].replace("Bba","BBA")
df["Contact: Educational Qualification"]=df["Contact: Educational Qualification"].replace("BBA Logistics","BBA")
df["Contact: Educational Qualification"]=df["Contact: Educational Qualification"].replace("BBA ug","BBA")
df["Contact: Educational Qualification"]=df["Contact: Educational Qualification"].replace("B.B.A","BBA")
df["Contact: Educational Qualification"]=df["Contact: Educational Qualification"].replace("BBA (distance)","BBA")
df["Contact: Educational Qualification"]=df["Contact: Educational Qualification"].replace("BBA in IBM","BBA")
df["Contact: Educational Qualification"]=df["Contact: Educational Qualification"].replace("bba","BBA")
df["Contact: Educational Qualification"]=df["Contact: Educational Qualification"].replace("Bachelor of Business Administration","BBA")
df["Contact: Educational Qualification"]=df["Contact: Educational Qualification"].replace("B.B.A","BBA")
df["Contact: Educational Qualification"]=df["Contact: Educational Qualification"].replace("I completed MBA with specialization in marketing field","MBA")
df["Contact: Educational Qualification"]=df["Contact: Educational Qualification"].replace("B. Com","B.com")

# %%
grouped = (df.groupby('Contact: Educational Qualification')['Course pitched'].value_counts().reset_index(name='Count').sort_values(by='Count', ascending=False))
grouped
# Out:
#     Contact: Educational Qualification     Course pitched  Count
# 15                               B.com  Digital Marketing     29
# 49                                 BSC  Digital Marketing     27
# 16                               B.com     Data Analytics     24
# 43                                  BE  Digital Marketing     23
# 92                                 MBA  Digital Marketing     22
# ..                                 ...                ...    ...
# 95                                 MBA                FSD      1
# 107                               Mcom     Data Analytics      1
# 100                                MCA       Data Science      1
# 121                non-it_professional                MSD      1
# 123                  postgraduate_(pg)     Data Analytics      1
#
# [127 rows x 3 columns]

# %%
df
# Out:
#          ID Pipeline Repeat deal Repeat inquiry              Stage  \
# 0     84490    Sales           N              Y    Tele Counselled
# 1     84138    Sales           N              N           New Lead
# 2     80194    Sales           N              N           New Lead
# 3     77118    Sales           N              N    Tele Counselled
# 4     89606    Sales           N              Y     Enquired Again
# ...     ...      ...         ...            ...                ...
# 1501  #####    Sales           N              N    Tele Counselled
# 1502  #####    Sales           N              N  Contact Attempted
# 1503  #####    Sales           N              N  Contact Attempted
# 1504  #####    Sales           N              N      Other Courses
# 1505  #####    Sales           N              N  Contact Attempted
#
#             Responsible                                          Deal Name  \
# 0     Sathiya Natarajan                   Complete CRM form "Navbar & CTA"
# ...

# %%
unique_qualifications = (
    pd.Series(df['Contact: Educational Qualification'].dropna().astype(str).unique())
    .sort_values()
    .reset_index(drop=True)
    .reset_index()
)

unique_qualifications.columns = ['Index', 'Educational Qualification']
print(unique_qualifications)
# Out:
#      Index                    Educational Qualification
# 0        0  "I’m in the final year of my B.Com degree".
# 1        1                                           10
# 2        2                                         10th
# 3        3                                   12+diploma
# 4        4                                         12th
# ..     ...                                          ...
# 215    215                          non-it_professional
# 216    216                            postgraduate_(pg)
# 217    217                                      student
# 218    218                           undergraduate_(ug)
# 219    219                                          ʙʙᴀ
#
# [220 rows x 2 columns]

# %%
unique_qualifications = (
    pd.Series(df['Contact: Educational Qualification'].dropna().astype(str).unique())
    .sort_values()
    .reset_index(drop=True)
    .reset_index()
)

unique_qualifications.columns = ['Index', 'Educational Qualification']
print(unique_qualifications)
# Out:
#      Index                    Educational Qualification
# 0        0  "I’m in the final year of my B.Com degree".
# 1        1                                           10
# 2        2                                         10th
# 3        3                                   12+diploma
# 4        4                                         12th
# ..     ...                                          ...
# 215    215                          non-it_professional
# 216    216                            postgraduate_(pg)
# 217    217                                      student
# 218    218                           undergraduate_(ug)
# 219    219                                          ʙʙᴀ
#
# [220 rows x 2 columns]

# %%
with pd.ExcelWriter("whytapfile.xlsx", engine='openpyxl') as writer:
    high_cover.to_excel(writer, sheet_name='conversion', index=False)
    pivot_summary .to_excel(writer, sheet_name='Sales_count', index=False)
    result.to_excel(writer, sheet_name='DA', index=False)
    unique_qualifications.to_excel(writer, sheet_name='edu', index=False)
    grouped.to_excel(writer, sheet_name='qual', index=False)
    month_wise.to_excel(writer, sheet_name='month_wise', index=False)

# %%
Conversion_performance= df.groupby("Source")["Closed"].value_counts().unstack(fill_value=0)
high_cover=Conversion_performance.sort_values(by=["yes","no"],ascending=[False,False]).reset_index()

# %%
df
# Out:
#          ID Pipeline Repeat deal Repeat inquiry              Stage  \
# 0     84490    Sales          NO            YES    Tele Counselled
# 1     84138    Sales          NO             NO           New Lead
# 2     80194    Sales          NO             NO           New Lead
# 3     77118    Sales          NO             NO    Tele Counselled
# 4     89606    Sales          NO            YES     Enquired Again
# ...     ...      ...         ...            ...                ...
# 1501  #####    Sales          NO             NO    Tele Counselled
# 1502  #####    Sales          NO             NO  Contact Attempted
# 1503  #####    Sales          NO             NO  Contact Attempted
# 1504  #####    Sales          NO             NO      Other Courses
# 1505  #####    Sales          NO             NO  Contact Attempted
#
#             Responsible                                          Deal Name  \
# 0     Sathiya Natarajan                   Complete CRM form "Navbar & CTA"
# ...

# %%
month=df.groupby("Created")["Closed"].value_counts().unstack(fill_value=0)

# %%
month
# Out:
# Closed      no  yes
# Created
# 2025-01-08  13    9
# 2025-01-09  12    1
# 2025-01-10  20    2
# 2025-02-08   9    4
# 2025-02-09  20    3
# ...         ..  ...
# 2025-10-10   3    0
# 2025-11-08   8    2
# 2025-11-09  14    8
# 2025-12-08   7    3
# 2025-12-09  17    3
#
# [88 rows x 2 columns]

# %%
month_yes=month_yess.sort_values(by=["yes","no"],ascending=[False,False]).reset_index()

# %%
# Group by 'Created' and count 'Closed' values
month = df.groupby("Created")["Closed"].value_counts().unstack(fill_value=0)

# Filter rows where 'yes' count is greater than 0
month_yess = month[month["yes"] > 0]

print(month_yess)
# Out:
# Closed               no  yes
# Created
# 2025-01-08 08:37:07   0    1
# 2025-01-08 09:51:22   0    1
# 2025-01-08 11:49:20   0    1
# 2025-01-08 12:43:34   0    1
# 2025-01-08 16:41:56   0    1
# ...                  ..  ...
# 2025-12-08 12:25:34   0    1
# 2025-12-08 17:36:05   0    1
# 2025-12-09 13:16:09   0    1
# 2025-12-09 18:47:47   0    1
# 2025-12-09 22:36:48   0    1
#
# [275 rows x 2 columns]

# %%
df_yes = df[df["Closed"] == "yes"]

# %%
month_wise= df_yes.groupby("Course pitched")["Month"].value_counts().reset_index().sort_values(by="count",ascending=False)
month_wise
# Out:
#        Course pitched   Month  count
# 9   Digital Marketing  Jul-25     18
# 10  Digital Marketing  Aug-25     10
# 0      Data Analytics  Jul-25      6
# 1      Data Analytics  May-25      5
# 11  Digital Marketing  Sep-25      5
# 2      Data Analytics  Sep-25      5
# 19                FSD  Oct-25      4
# 12  Digital Marketing  Apr-25      4
# 24                MSD  Sep-25      4
# 18                FSD  Jul-25      4
# 3      Data Analytics  Aug-25      3
# 20                FSD  Aug-25      3
# 13  Digital Marketing  Jan-25      3
# 25                MSD  Aug-25      2
# 22                FSD  Sep-25      2
# 5      Data Analytics  Oct-25      2
# 4      Data Analytics  Nov-25      2
# 16  Digital Marketing  Oct-25      2
# 15  Digital Marketing  May-25      2
# 14  Digital Marketing  Jun-25      2
# 21                FSD  May-25      2
# 8        Data Science  Jul-25      1
# 6      Data Analytics  Apr-25      1
# 7      Data Analytics  Dec-25      1
# ...

# %%
df['Created']=pd.to_datetime(df['Created'])
df["Created"]
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_16856\3015420661.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Created']=pd.to_datetime(df['Created'])
# 0      2025-09-01
# 1      2025-09-01
# 2      2025-12-01
# 3      2025-09-01
# 4      2025-09-01
#           ...
# 1501   2025-02-01
# 1502   2025-02-01
# 1503   2025-02-01
# 1504   2025-08-01
# 1505   2025-03-01
# Name: Created, Length: 1506, dtype: datetime64[ns]

# %%
df["month"]=df["Created"].dt.strftime("%B-%Y")

# %%
df["month"]
# Out:
# 0       September-2025
# 1       September-2025
# 2        December-2025
# 3       September-2025
# 4       September-2025
#              ...
# 1501     February-2025
# 1502     February-2025
# 1503     February-2025
# 1504       August-2025
# 1505        March-2025
# Name: Created, Length: 1506, dtype: object

# %%
Conversion_performance= df.groupby("Source")["Closed"].value_counts().unstack(fill_value=0)
Conversion_performance
# Out:
# Closed              no  yes
# Source
# CRM form            21    4
# Call                15    5
# E-Mail               1    0
# Event                1    1
# Google AD           23   15
# Influencer          11    0
# Instagram           48    6
# Meta AD            816  182
# Repeat sales        17   10
# Student Reference    2    1
# Walk-in              5    1
# Website             62   12
# WhatsApp           173   66
# not selected         0    1

# %%
yes= df.groupby("Responsible")["Closed"].value_counts().unstack(fill_value=0)
yes
# Out:
# Closed                     no  yes
# Responsible
# Ahila M                     2    0
# Dhanalakshmi D             37    5
# Gayyo Lovees               48    1
# Harini P                  139   49
# Kaveri C                  149   43
# Meena Arunachalam         110   32
# Monisha R                   2    0
# Navanitha Sakthi           40    0
# Naveen kumar               55    9
# Pratheep Kumar P          143   19
# Rajalakshmi Govindarajan  142   18
# Ramya Sathish              47   74
# Sathiya Natarajan         110   15
# Sophia N D                153   31
# Supraja Baalajee           12    4
# Vignesh R                  13    4

# %%
sale_summary= yes_count_by_resp.groupby(["Responsible",'Course pitched']).size().reset_index(name="count")
sale_summary
# Out:
#                  Responsible                           Course pitched  count
# 0             Dhanalakshmi D                           Data Analytics      6
# 1             Dhanalakshmi D                        Digital Marketing     18
# 2             Dhanalakshmi D                                      FSD     13
# 3               Gayyo Lovees                             Data Science      1
# 4               Gayyo Lovees                        Digital Marketing     22
# 5               Gayyo Lovees                                      FSD      1
# 6                   Harini P                           Data Analytics      7
# 7                   Harini P                             Data Science      3
# 8                   Harini P                        Digital Marketing     62
# 9                   Harini P                                      FSD     12
# 10                  Harini P                                      MSD      2
# ...

# %%
pivot_summary = sale_summary.pivot_table(
    index=['Responsible', 'Course pitched'],
    columns='Closed',
    values='count',
    fill_value=0
).reset_index()
pivot_summary
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_16856\571553024.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   pivot_summary = sale_summary.pivot_table(
# Closed Responsible                           Course pitched   no  yes
# 0          Ahila M  Basic to Advanced Video Editing with AI  0.0  0.0
# 1          Ahila M                           Data Analytics  0.0  0.0
# 2          Ahila M                             Data Science  0.0  0.0
# 3          Ahila M                        Digital Marketing  0.0  0.0
# 4          Ahila M                                      FSD  0.0  0.0
# ..             ...                                      ...  ...  ...
# 91       Vignesh R                           Data Analytics  2.0  1.0
# 92       Vignesh R                             Data Science  0.0  0.0
# ...

# %%
da_df = df[(df['Course pitched'] == 'Data Analytics') &(df["Closed"] == "yes" )]
result = da_df[['Responsible','Contact: First name', 'Course pitched']].reset_index()

result
# Out:
#     index               Responsible Contact: First name  Course pitched
# 0     170                  Harini P                Asha  Data Analytics
# 1     374                  Kaveri C      john william V  Data Analytics
# 2     413                  Kaveri C      john william V  Data Analytics
# 3     523         Meena Arunachalam                 கவி  Data Analytics
# 4     526         Meena Arunachalam              Sanjay  Data Analytics
# 5     529         Meena Arunachalam          Harisankar  Data Analytics
# 6     567         Meena Arunachalam                 கவி  Data Analytics
# 7     573         Meena Arunachalam              Sanjay  Data Analytics
# 8     608         Meena Arunachalam       BABYSHALINI R  Data Analytics
# 9     617         Meena Arunachalam          Harisankar  Data Analytics
# 10    689              Naveen kumar         Sivaranjini  Data Analytics
# 11    730              Naveen kumar         Sivaranjini  Data Analytics
# ...

# %%
grouped = df.groupby('Contact: Educational Qualification')['Course pitched'].value_counts().reset_index()
grouped
# Out:
#     Contact: Educational Qualification     Course pitched  count
# 0                           12+diploma     Data Analytics      1
# 1                                 12th                FSD      1
# 2                           8098783393     Data Analytics      1
# 3                           9344759243  Digital Marketing      1
# 4                           9384533188  Digital Marketing      1
# ..                                 ...                ...    ...
# 122                  postgraduate_(pg)                FSD      2
# 123                  postgraduate_(pg)     Data Analytics      1
# 124                            student     Data Analytics      4
# 125                            student  Digital Marketing      4
# 126                            student                FSD      3
#
# [127 rows x 3 columns]
